# %%
import pandas as pd
from src.apps.connectors import conectores as con

# %%
params =pd.read_excel("/workspaces/proyecto-aula-viernes/src/fixtures/PARAMETROS.xlsx")

# %%
for ticker in params["ticket"].values:
    print(con.download_from_yfinance(ticker, '2020-01-01', '2020-12-31'))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open    Volume
# Ticker             F         F         F         F         F
# Date
# 2020-01-02  6.952614  6.952614  6.782858  6.856665  43425700
# 2020-01-03  6.797622  6.915713  6.753337  6.871429  45040800
# 2020-01-06  6.760717  6.768098  6.686911  6.716434  43372300
# 2020-01-07  6.827144  6.827144  6.731195  6.790241  44984100
# 2020-01-08  6.827144  6.864048  6.768099  6.812382  45994900
# ...              ...       ...       ...       ...       ...
# 2020-12-23  6.748089  6.778114  6.605471  6.620484  54086700
# 2020-12-24  6.650510  6.770610  6.605473  6.763104  27927000
# 2020-12-28  6.673027  6.740582  6.650508  6.695545  38068400
# 2020-12-29  6.620484  6.703053  6.590460  6.703053  37537900
# 2020-12-30  6.650510  6.695547  6.612979  6.627991  38461900
#
# [252 rows x 5 columns]
# ...

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.400528   72.460791   71.156689   71.409793  135480400
# 2020-01-03   71.696648   72.455966   71.472469   71.629153  146322800
# 2020-01-06   72.267921   72.306491   70.568495   70.819193  118387200
# 2020-01-07   71.928062   72.533103   71.708703   72.277586  108872000
# 2020-01-08   73.085091   73.386408   71.631537   71.631537  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-23  127.364128  128.793751  127.189063  128.531176   88223700
# 2020-12-24  128.346390  129.795483  127.500283  127.714243   54930100
# 2020-12-28  132.936829  133.568975  129.844136  130.310967  124486200
# 2020-12-29  131.166809  134.979174  130.651363  134.259502  121047300
# ...

# %%
print(con.download_from_yfinance('UEC', '2020-01-01', '2020-12-31'))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price      Close  High   Low  Open   Volume
# Ticker       UEC   UEC   UEC   UEC      UEC
# Date
# 2020-01-02  0.93  0.93  0.91  0.93   392400
# 2020-01-03  0.91  0.93  0.91  0.93   509900
# 2020-01-06  0.90  0.93  0.89  0.91   813700
# 2020-01-07  0.89  0.92  0.89  0.91   286900
# 2020-01-08  0.91  0.91  0.87  0.89   781900
# ...          ...   ...   ...   ...      ...
# 2020-12-23  1.75  1.80  1.63  1.65  3220000
# 2020-12-24  1.76  1.79  1.66  1.79  1387000
# 2020-12-28  1.89  2.02  1.79  1.80  5660600
# 2020-12-29  1.83  2.00  1.81  1.99  2869800
# 2020-12-30  1.85  1.89  1.80  1.84  2425400
#
# [252 rows x 5 columns]

# %%
from datetime import datetime, timedelta
import dukascopy_python
from dukascopy_python.instruments import INSTRUMENT_VCCY_BTC_USD

start = datetime(2025, 10, 20)
end = datetime.now()
instrument = INSTRUMENT_VCCY_BTC_USD
interval = dukascopy_python.INTERVAL_SEC_30
offer_side = dukascopy_python.OFFER_SIDE_BID

df = dukascopy_python.fetch(
    instrument,
    interval,
    offer_side,
    start,
    end,
)

df
# Out:
# INFO:DUKASCRIPT:current timestamp :2025-10-23T12:02:30
# INFO:DUKASCRIPT:current timestamp :2025-10-27T03:27:30
# INFO:DUKASCRIPT:current timestamp :2025-10-30T16:39:00
# INFO:DUKASCRIPT:current timestamp :2025-11-03T08:37:30
# INFO:DUKASCRIPT:current timestamp :2025-11-06T20:15:00
# INFO:DUKASCRIPT:current timestamp :2025-11-10T09:28:30
# INFO:DUKASCRIPT:current timestamp :2025-11-13T20:54:30
# INFO:DUKASCRIPT:current timestamp :2025-11-17T10:00:30
# INFO:DUKASCRIPT:current timestamp :2025-11-20T21:47:00
# INFO:DUKASCRIPT:current timestamp :2025-11-24T09:21:30
# INFO:DUKASCRIPT:current timestamp :2025-11-27T20:51:30
# INFO:DUKASCRIPT:current timestamp :2025-12-01T20:01:30
# INFO:DUKASCRIPT:current timestamp :2025-12-05T07:37:30
# INFO:DUKASCRIPT:current timestamp :2025-12-08T22:10:00
# INFO:DUKASCRIPT:current timestamp :2025-12-12T10:24:30
# INFO:DUKASCRIPT:current timestamp :2025-12-16T04:21:00
# INFO:DUKASCRIPT:current timestamp :2025-12-19T17:06:00
# ...
